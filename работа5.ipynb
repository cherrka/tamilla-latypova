# %% [markdown]
# <a href="https://colab.research.google.com/github/cherrka/tamilla-latypova/blob/main/%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Инициализация нового локального репозитория - git init![Снимок экрана 2025-04-22 200241.png](data:image/png;base64,...)

# %% [markdown]
# 2.Добавление файлов в индекс для коммита - git add <file>![Снимок экрана 2025-04-22 200423.png](data:image/png;base64,...)

# %% [markdown]
# 3.Создание нового коммита - git commit -m "Commit message"![Снимок экрана 2025-04-22 200740.png](data:image/png;base64,...)

# %% [markdown]
# 4.Просмотр истории коммитов - git log![Снимок экрана 2025-04-22 200825.png](data:image/png;base64,...)

# %% [markdown]
# 5.Просмотр изменений в файлах перед коммитом - git diff![Снимок экрана 2025-04-22 201239.png](data:image/png;base64,...)

# %% [markdown]
# 6.Откат изменений в файле до предыдущего коммита - git checkout -- <file>![Снимок экрана 2025-04-22 201938.png](data:image/png;base64,...)

# %% [markdown]
# 7.Создание новой ветки - git branch <branch_name>![Снимок экрана 2025-04-22 202141.png](data:image/png;base64,...)

# %% [markdown]
# 8.Переключение между ветками - git checkout <branch_name>![Снимок экрана 2025-04-22 202239.png](data:image/png;base64,...)

# %% [markdown]
# 9.Слияние веток - git merge <branch_name>![Снимок экрана 2025-04-22 202345.png](data:image/png;base64,...)

# %% [markdown]
# 10.Удаление ветки - git branch -d <branch_name>![Снимок экрана 2025-04-22 202901.png](data:image/png;base64,...)

# %% [markdown]
# 12.![Снимок экрана 2025-04-23 191103.png](data:image/png;base64,...)Удаление файла из репозитория и истории коммитов - git rm <file>

# %% [markdown]
# 13.Игнорирование файлов и папок с помощью .gitignore - создание и редактирование файла .gitignore![Снимок экрана 2025-04-23 191737.png](data:image/png;base64,...)

# %% [markdown]
# 14.Просмотр различий между ветками - git diff <branch1> <branch2>![Снимок экрана 2025-04-23 194159.png](data:image/png;base64,...)

# %% [markdown]
# 15.Отмена изменений в файле после добавления в индекс - git reset HEAD <file>![Снимок экрана 2025-04-23 194817.png](data:image/png;base64,...)

# %% [markdown]
# 16.Просмотр информации о состоянии репозитория - git status![Снимок экрана 2025-04-23 194907.png](data:image/png;base64,...)

# %% [markdown]
# 17.Переименование файлов - git mv <old_file> <new_file>![Снимок экрана 2025-04-23 195053.png](data:image/png;base64,...)![Снимок экрана 2025-04-23 195037.png](data:image/png;base64,...)

# %% [markdown]
# 18.Отображение информации о коммите - git show <commit_id>![Снимок экрана 2025-04-23 195250.png](data:image/png;base64,...)

# %% [markdown]
# 19.Возврат к определенному коммиту - git checkout <commit_id>![Снимок экрана 2025-04-23 195854.png](data:image/png;base64,...)

# %% [markdown]
# 20.Создание и применение патчей - git format-patch и git apply![Снимок экрана 2025-04-23 200612.png](data:image/png;base64,...)

# %% [markdown]
# 21.Изменение порядка коммитов - git rebase -i

# %% [markdown]
# 22.Изменение авторства коммитов - git commit --amend --author="Author Name <email>"![Снимок экрана 2025-04-23 204109.png](data:image/png;base64,...)

# %% [markdown]
# 23.Изменение истории коммитов с помощью rebase - git rebase

# %% [markdown]
# 24.Использование stash для временного сохранения изменений - git stash и git stash apply![Снимок экрана 2025-04-24 112153.png](data:image/png;base64,...)

# %% [markdown]
# 25.Применение изменений из одной ветки в другую с помощью cherry-pick - git cherry-pick <commit_id>![Снимок экрана 2025-04-24 113113.png](data:image/png;base64,...)

# %% [markdown]
# 26.Просмотр информации о ветках и удаленных репозиториях - git branch, git remote -v![Снимок экрана 2025-04-24 113213.png](data:image/png;base64,...)

# %% [markdown]
# 27.Изменение URL удаленного репозитория - git remote set-url origin <new_url>![Снимок экрана 2025-04-24 113702.png](data:image/png;base64,...)

# %% [markdown]
# 28.Удаление коммитов из истории - git reset или git rebase -i![Снимок экрана 2025-04-24 114422.png](data:image/png;base64,...)

# %% [markdown]
# 29.Использование алиасов для команд Git - git config --global alias.<alias_name> "<command>"![Снимок экрана 2025-04-24 114625.png](data:image/png;base64,...)

# %% [markdown]
# 30.Использование подмодулей для работы с вложенными репозиториями - git submodule

# %% [markdown]
# 1.Клонировать удаленный репозиторий на локальную машину. (git clone)![Снимок экрана 2025-04-24 115927.png](data:image/png;base64,...)

# %% [markdown]
# 2.Добавить новый удаленный репозиторий в существующий проект. (git remote add)![Снимок экрана 2025-04-24 120721.png](data:image/png;base64,...)

# %% [markdown]
# 3.Посмотреть список удаленных репозиториев, связанных с локальным проектом. (git remote -v)![Снимок экрана 2025-04-24 120754.png](data:image/png;base64,...)

# %% [markdown]
# 4.Посмотреть информацию о удаленном репозитории (например, URL). (git remote show)![Снимок экрана 2025-04-24 121009.png](data:image/png;base64,...)

# %% [markdown]
# 5.Изменить URL удаленного репозитория. (git remote set-url)![Снимок экрана 2025-04-24 121233.png](data:image/png;base64,...)

# %% [markdown]
# 6.Добавить новый файл в удаленный репозиторий. (git add, git commit, git push)![Снимок экрана 2025-04-24 121355.png](data:image/png;base64,...)

# %% [markdown]
# 7.Закоммитить изменения и отправить их в удаленный репозиторий. (git commit, git push)![Снимок экрана 2025-04-24 121724.png](data:image/png;base64,...)

# %% [markdown]
# 8.Посмотреть различия между локальным и удаленным репозиториями. (git diff, git difftool)![Снимок экрана 2025-04-24 122501.png](data:image/png;base64,...)

# %% [markdown]
# 9.Получить изменения из удаленного репозитория на локальную машину. (git fetch, git pull)![Снимок экрана 2025-04-24 122740.png](data:image/png;base64,...)

# %% [markdown]
# 10.Отправить ветку в удаленный репозиторий. (git push)![Снимок экрана 2025-04-24 123139.png](data:image/png;base64,...)

# %% [markdown]
# 11.Удалить ветку из удаленного репозитория. (git push origin --delete)![Снимок экрана 2025-04-24 123252.png](data:image/png;base64,...)

# %% [markdown]
# 12.Переименовать удаленную ветку. (git branch -m, git push origin :old_branch_name new_branch_name)![Снимок экрана 2025-04-24 123641.png](data:image/png;base64,...)![Снимок экрана 2025-04-24 123711.png](data:image/png;base64,...)

# %% [markdown]
# 13.Переместить удаленную ветку. (git push origin :branch_name destination_branch_name)![Снимок экрана 2025-04-24 124329.png](data:image/png;base64,...)

# %% [markdown]
# 14.Создать тег и отправить его в удаленный репозиторий. (git tag, git push --tags)![Снимок экрана 2025-04-24 124527.png](data:image/png;base64,...)

# %% [markdown]
# 15.Удалить тег из удаленного репозитория. (git push origin --delete tag_name)![Снимок экрана 2025-04-24 124637.png](data:image/png;base64,...)

# %% [markdown]
# 16.Просмотреть историю коммитов на удаленном репозитории. (git log, gitk, gitg)![Снимок экрана 2025-04-24 124726.png](data:image/png;base64,...)

# %% [markdown]
# 17.Отменить последний коммит и отправить изменения в удаленный репозиторий. (git reset, git push -f)![Снимок экрана 2025-04-24 124844.png](data:image/png;base64,...)

# %% [markdown]
# 18.Просмотреть информацию о ветках на удаленном репозитории. (git branch -r)![Снимок экрана 2025-04-24 124922.png](data:image/png;base64,...)

# %% [markdown]
# 19.Изменить настройки удаленного репозитория (например, upstream). (git remote set-url)![Снимок экрана 2025-04-24 125454.png](data:image/png;base64,...)

# %% [markdown]
# 20.Поделиться ссылкой на удаленный репозиторий с коллегами. (ссылка на репозиторий)
# https://github.com/cherrka/kkk

# %% [markdown]
# 21.Посмотреть список веток на удаленном репозитории. (git branch -r)![Снимок экрана 2025-04-24 125655.png](data:image/png;base64,...)

# %% [markdown]
# 22.Изменить права доступа к удаленному репозиторию. (настройки удаленного сервера)

# %% [markdown]
# 23.Просмотреть список вкладчиков в удаленном репозитории. (настройки удаленного сервера)

# %% [markdown]
# 24.Изменить сообщение последнего коммита и отправить изменения в удаленный репозиторий. (git commit --amend, git push -f)![Снимок экрана 2025-04-24 130120.png](data:image/png;base64,...)

# %% [markdown]
# 25.Сравнить различия между локальной и удаленной веткой. (git diff, git difftool)![Снимок экрана 2025-04-24 130245.png](data:image/png;base64,...)

# %% [markdown]
# 26.Удалить файл из удаленного репозитория. (git rm, git commit, git push)![Снимок экрана 2025-04-24 130750.png](data:image/png;base64,...)

# %% [markdown]
# 27.Восстановить удаленный файл из истории удаленного репозитория. (git checkout)![Снимок экрана 2025-04-24 131441.png](data:image/png;base64,...)![Снимок экрана 2025-04-24 131429.png](data:image/png;base64,...)

# %% [markdown]
# 28.Создать новую ветку на удаленном репозитории. (git push origin new_branch)![Снимок экрана 2025-04-24 131911.png](data:image/png;base64,...)

# %% [markdown]
# 29.Просмотреть список тегов на удаленном репозитории. (git tag, git show)![Снимок экрана 2025-04-24 131947.png](data:image/png;base64,...)

# %% [markdown]
# 30.Сравнить различия между разными версиями удаленного репозитория. (git diff, git difftool)![Снимок экрана 2025-04-24 132119.png](data:image/png;base64,...)

# %% [markdown]
# 31.Изменить сообщение коммита, который уже был отправлен в удаленный репозиторий. (git commit --amend, git push -f)![Снимок экрана 2025-04-24 132331.png](data:image/png;base64,...)

# %% [markdown]
# 32.Отменить последний коммит, но оставить изменения в рабочей директории. (git reset --soft HEAD^)![Снимок экрана 2025-04-24 132540.png](data:image/png;base64,...)

# %% [markdown]
# 33.Переименовать файл и отправить изменения в удаленный репозиторий. (git mv, git commit, git push)![Снимок экрана 2025-04-24 132735.png](data:image/png;base64,...)

# %% [markdown]
# 34.Отобразить информацию о удаленном репозитории. (git remote show)![Снимок экрана 2025-04-24 132814.png](data:image/png;base64,...)

# %% [markdown]
# 35.Удалить ветку на удаленном репозитории. (git push origin --delete branch_name)![Снимок экрана 2025-04-24 134247.png](data:image/png;base64,...)

# %% [markdown]
# 36.Просмотреть список изменений, ожидающих отправки в удаленный репозиторий. (git status)![Снимок экрана 2025-04-24 134339.png](data:image/png;base64,...)

# %% [markdown]
# 37.Отменить локальные изменения и обновить содержимое файлов до последней версии из удаленного репозитория. (git checkout -- <file>, git fetch, git reset --hard origin/<branch>)![Снимок экрана 2025-04-24 134828.png](data:image/png;base64,...)

# %% [markdown]
# 38.Переключиться на другую ветку и обновить содержимое до последней версии из удаленного репозитория. (git checkout <branch>, git pull)
# ![Снимок экрана 2025-04-24 135647.png](data:image/png;base64,...)

# %% [markdown]
# 39.Перенести локальные коммиты на другую ветку и отправить изменения в удаленный репозиторий. (git cherry-pick, git rebase, git push)![Снимок экрана 2025-04-24 140420.png](data:image/png;base64,...)

# %% [markdown]
# 40.Изменить историю коммитов перед отправкой в удаленный репозиторий. (git rebase -i, git push -f)

# %% [markdown]
# 41.Просмотреть различия между двумя коммитами в удаленном репозитории. (git diff <commit1> <commit2>)![Снимок экрана 2025-04-24 140829.png](data:image/png;base64,...)

# %% [markdown]
# 42.Изменить настройки отслеживания ветки на удаленном репозитории. (git branch --set-upstream-to)![Снимок экрана 2025-04-24 141027.png](data:image/png;base64,...)

# %% [markdown]
# 43.Просмотреть информацию о вкладчиках в удаленном репозитории. (настройки удаленного сервера)![Снимок экрана 2025-04-24 141207.png](data:image/png;base64,...)

# %% [markdown]
# 44.Просмотреть список удаленных веток. (git branch -r)![Снимок экрана 2025-04-24 141248.png](data:image/png;base64,...)

# %% [markdown]
# 45.Отправить локальные теги в удаленный репозиторий. (git push --tags)![Снимок экрана 2025-04-24 141346.png](data:image/png;base64,...)

# %% [markdown]
# 46.Изменить конфигурационные параметры удаленного репозитория. (настройки удаленного сервера)

# %% [markdown]
# 47.Сравнить локальную ветку с удаленной версией. (git diff <local_branch> origin/<remote_branch>)![Снимок экрана 2025-04-24 141922.png](data:image/png;base64,...)

# %% [markdown]
# 48.Изменить сообщение коммита, который еще не был отправлен в удаленный репозиторий. (git commit --amend)

# %% [markdown]
# 49.Восстановить удаленную ветку из удаленного репозитория. (git fetch, git checkout -b <branch> origin/<branch>)![Снимок экрана 2025-04-24 142905.png](data:image/png;base64,...)

# %% [markdown]
# 50.Отобразить информацию о ветках на удаленном репозитории. (git ls-remote, git remote show)![Снимок экрана 2025-04-24 143008.png](data:image/png;base64,...)
